# %% [markdown]
# # LOADING THE IMPORTTANT LIBRARY

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOADING THE DATA USING PANDAS

# %%
df=pd.read_csv("D:\\KAGGLE DATASET\\data.csv")
df.head()
# Out:
#                         AppsFlyer ID        Medium       CUID  Dep Amnt
# 0  1639054416583-4328308471070739413  landing_page  127186860     16831
# 1  1639054948796-8071487204247954627  landing_page  127310439       320
# 2  1639289482157-2757509565544512908  landing_page  127332457       280
# 3  1638882829328-6024121239919248175  landing_page  127291988       276
# 4  1639193759307-8187307056047606274  landing_page  127322275        90

# %% [markdown]
# # DESCRIPTIVE ANALYTICS

# %%
df.shape
# Out:
# (5027, 4)

# %% [markdown]
# CHECKING THE ROW AND COLUMN OF DATAFRAME

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5027 entries, 0 to 5026
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AppsFlyer ID  5027 non-null   object
#  1   Medium        5027 non-null   object
#  2   CUID          5027 non-null   int64
#  3   Dep Amnt      5027 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 157.2+ KB

# %% [markdown]
# CHECKING THE DATA TYPE OF DATAFRAME

# %%
df.describe()
# Out:
#                CUID       Dep Amnt
# count  5.027000e+03    5027.000000
# mean   1.262535e+08     474.665606
# std    3.913964e+06    5087.501679
# min    1.000168e+08      20.000000
# 25%    1.272002e+08      20.000000
# 50%    1.272494e+08      90.000000
# 75%    1.272892e+08     228.000000
# max    1.273473e+08  320865.000000

# %% [markdown]
# CHECKING THE CENTRAL TENDENCY,MAXIMUM,MINIMUM,VARIANCE,STANDARDDEVIATION AND COUNT

# %%
df.isnull().sum()
# Out:
# AppsFlyer ID    0
# Medium          0
# CUID            0
# Dep Amnt        0
# dtype: int64

# %% [markdown]
# CHECKING THE NULL VALUE IN DATAFRAME IN TERM OF VALUE

# %%
plt.figure(figsize=(10,5))
plt.title("CHECKING THE NULL VALUE IN DATAFRAME")
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# CHECKING THE NULL VALUE IN DATAFRAME IN VISUALIZATION FORM

# %% [markdown]
# # DATA PROFILING

# %% [markdown]
#  COLUMN PROFILING

# %%
for col in df.columns:
    print(col)
    print(end="\n")
    print(df[str(col)].value_counts())
    print('================================================================================================================')
# Out:
# AppsFlyer ID
#
# 1637125558765-8034454258143174578    1
# 1637726749024-1935852652588383278    1
# 1638807528890-8027243957929101165    1
# 1637345580566-3838328406068034348    1
# 1635182314263-2779545167046050089    1
#                                     ..
# 1637047476358-814500685392676540     1
# 1638815352185-1122990257516680144    1
# 1639146421894-1181822214295024451    1
# 1637764316837-2781128574041225895    1
# 1639367555414-3327861802228558570    1
# Name: AppsFlyer ID, Length: 5027, dtype: int64
# ...
# Medium
#
# landing_page       2494
# appmontize         2138
# GoogleAds           188
# mediascopy_int       65
# digirovers_int       31
# intellectads         20
# glance_int           18
# appnext_int          15
# phonepe_int          13
# affleagency          10
# taboola_int           8
# digiroverssolin       7
# sgsglobalservic       5
# freekaamaal_int       5
# gmsinternet_int       4
# game_invite           4
# inuxudmt_int          1
# Social_facebook       1
# ...

# %% [markdown]
# CHECKING THE UNIQUE VALUE AND COUNT OF THE VALUE IN EVERY COLUMN

# %%
for col in df.columns:
    print(col)
    print(end="\n")
    print(df[str(col)].value_counts(normalize=True)*100)
    print('================================================================================================================')
# Out:
# AppsFlyer ID
#
# 1637125558765-8034454258143174578    0.019893
# 1637726749024-1935852652588383278    0.019893
# 1638807528890-8027243957929101165    0.019893
# 1637345580566-3838328406068034348    0.019893
# 1635182314263-2779545167046050089    0.019893
#                                        ...
# 1637047476358-814500685392676540     0.019893
# 1638815352185-1122990257516680144    0.019893
# 1639146421894-1181822214295024451    0.019893
# 1637764316837-2781128574041225895    0.019893
# 1639367555414-3327861802228558570    0.019893
# Name: AppsFlyer ID, Length: 5027, dtype: float64
# ...
# Medium
#
# landing_page       49.612095
# appmontize         42.530336
# GoogleAds           3.739805
# mediascopy_int      1.293018
# digirovers_int      0.616670
# intellectads        0.397852
# glance_int          0.358066
# appnext_int         0.298389
# phonepe_int         0.258604
# affleagency         0.198926
# taboola_int         0.159141
# digiroverssolin     0.139248
# ...

# %% [markdown]
# CHECKING THE  WEIGHTAGE OF EVERY VALUE IN DATA FRANE

# %%
df['Medium'].value_counts()
# Out:
# landing_page       2494
# appmontize         2138
# GoogleAds           188
# mediascopy_int       65
# digirovers_int       31
# intellectads         20
# glance_int           18
# appnext_int          15
# phonepe_int          13
# affleagency          10
# taboola_int           8
# digiroverssolin       7
# sgsglobalservic       5
# freekaamaal_int       5
# gmsinternet_int       4
# game_invite           4
# inuxudmt_int          1
# Social_facebook       1
# Name: Medium, dtype: int64

# %%
landing_pagedata=df[df['Medium']=='landing_page']
appmontizedata=df[df['Medium']=='appmontize']
GoogleAdsdata=df[df['Medium']=='GoogleAds']
mediascopy_intdata=df[df['Medium']=='mediascopy_int']
digirovers_intdata=df[df['Medium']=='digirovers_int']
glance_intdata=df[df['Medium']=='intellectads']
appnext_intdata=df[df['Medium']=='appnext_int']
phonepe_intdata=df[df['Medium']=='phonepe_int']
taboola_intdata=df[df['Medium']=='taboola_int']
sgsglobalservicdata=df[df['Medium']=='sgsglobalservic']
freekaamaal_intdata=df[df['Medium']=='freekaamaal_int']
gmsinternet_intdata=df[df['Medium']=='gmsinternet_int']
game_invitedata=df[df['Medium']=='game_invite']
inuxudmt_intdata=df[df['Medium']=='inuxudmt_int']
Social_facebookdata=df[df['Medium']=='Social_facebook']
