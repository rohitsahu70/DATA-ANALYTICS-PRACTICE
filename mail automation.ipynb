# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# %%
mail_content = "ROHIT SAHU"
#The mail addresses and password
sender_address = 'rohitsahu70498@gmail.com'
sender_pass = 'rwcgtwvyvvnkxveu'
receiver_address = 'rohitsahu704980@gmail.com'

# %%
#Setup the MIME
message = MIMEMultipart()
message['From'] = sender_address
message['To'] = receiver_address
message['Subject'] = 'Multi attachment hogyaa .'

# %%
#The subject line
#The body and the attachments for the mail
message.attach(MIMEText(mail_content, 'plain'))
message.attach("""\
<!DOCTYPE html>
<html>
    <body>
        <h1 style="color:SlateGray;">This is an HTML Email!</h1>
    </body>
</html>
""", subtype='html')
attach_file_name = r'C:\Users\rohit\Desktop\Activity 3-converted.pdf'
attach_file_name1 = r'C:\Users\rohit\Desktop\Activity 3web.pdf'
attach_file = open(attach_file_name, 'rb') # Open the file as binary mode
attach_file1 = open(attach_file_name1, 'rb')
payload = MIMEBase('application', 'octate-stream')

payload1 = MIMEBase('application', 'octate-stream')

payload.set_payload((attach_file).read())
payload1.set_payload((attach_file1).read())
encoders.encode_base64(payload) #encode the attachment
encoders.encode_base64(payload1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-650c7d5ac9ab> in <module>
#       2 #The body and the attachments for the mail
#       3 message.attach(MIMEText(mail_content, 'plain'))
# ----> 4 message.attach("""\
#       5 <!DOCTYPE html>
#       6 <html>
#
# TypeError: attach() got an unexpected keyword argument 'subtype'

# %%
#add payload header with filename
payload.add_header('Content-Decomposition', 'attachment', filename=attach_file_name)
payload1.add_header('Content-Decomposition', 'attachment', filename=attach_file_name1)
message.attach(payload)
message.attach(payload1)

# %%
#Create SMTP session for sending the mail
session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
session.starttls() #enable security
session.login(sender_address, sender_pass) #login with mail_id and password
text = message.as_string()
session.sendmail(sender_address, receiver_address, text)
session.quit()
print('Mail Sent')
